# %% [markdown]
# <a href="https://colab.research.google.com/github/PravallikaSomisetti/python/blob/main/skillcraft_task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Sudoku Solver using Backtracking Algorithm

def print_board(board):
    """Function to print the Sudoku board in a readable format."""
    for i in range(9):
        if i % 3 == 0 and i != 0:
            print("-" * 21)
        for j in range(9):
            if j % 3 == 0 and j != 0:
                print("|", end=" ")
            print(board[i][j] if board[i][j] != 0 else ".", end=" ")
        print()


def is_valid(board, row, col, num):
    """Check if 'num' can be placed at board[row][col] without breaking Sudoku rules."""
    # Check row
    if num in board[row]:
        return False

    # Check column
    for i in range(9):
        if board[i][col] == num:
            return False

    # Check 3x3 box
    box_start_row = (row // 3) * 3
    box_start_col = (col // 3) * 3

    for i in range(3):
        for j in range(3):
            if board[box_start_row + i][box_start_col + j] == num:
                return False

    return True


def solve(board):
    """Recursive backtracking function to solve the Sudoku puzzle."""
    for row in range(9):
        for col in range(9):
            if board[row][col] == 0:  # Empty cell
                for num in range(1, 10):
                    if is_valid(board, row, col, num):
                        board[row][col] = num

                        if solve(board):
                            return True

                        board[row][col] = 0  # Backtrack

                return False  # No valid number found
    return True


# Sample Sudoku Puzzle (0 means empty)
board = [
    [5, 3, 0, 0, 7, 0, 0, 0, 0],
    [6, 0, 0, 1, 9, 5, 0, 0, 0],
    [0, 9, 8, 0, 0, 0, 0, 6, 0],
    [8, 0, 0, 0, 6, 0, 0, 0, 3],
    [4, 0, 0, 8, 0, 3, 0, 0, 1],
    [7, 0, 0, 0, 2, 0, 0, 0, 6],
    [0, 6, 0, 0, 0, 0, 2, 8, 0],
    [0, 0, 0, 4, 1, 9, 0, 0, 5],
    [0, 0, 0, 0, 8, 0, 0, 7, 9]
]

# Solve and print result
print("Original Sudoku Puzzle:\n")
print_board(board)

if solve(board):
    print("\nSolved Sudoku Puzzle:\n")
    print_board(board)
else:
    print("No solution exists for the given Sudoku.")
# Out:
# Original Sudoku Puzzle:
#
# 5 3 . | . 7 . | . . .
# 6 . . | 1 9 5 | . . .
# . 9 8 | . . . | . 6 .
# ---------------------
# 8 . . | . 6 . | . . 3
# 4 . . | 8 . 3 | . . 1
# 7 . . | . 2 . | . . 6
# ---------------------
# . 6 . | . . . | 2 8 .
# . . . | 4 1 9 | . . 5
# . . . | . 8 . | . 7 9
#
# Solved Sudoku Puzzle:
#
# 5 3 4 | 6 7 8 | 9 1 2
# 6 7 2 | 1 9 5 | 3 4 8
# 1 9 8 | 3 4 2 | 5 6 7
# ---------------------
# 8 5 9 | 7 6 1 | 4 2 3
# 4 2 6 | 8 5 3 | 7 9 1
# 7 1 3 | 9 2 4 | 8 5 6
# ---------------------
# 9 6 1 | 5 3 7 | 2 8 4
# 2 8 7 | 4 1 9 | 6 3 5
# 3 4 5 | 2 8 6 | 1 7 9
