# %% [markdown]
# <a href="https://colab.research.google.com/github/PravallikaSomisetti/python/blob/main/zilllionskills_2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Simple Command-line To-Do List Application

todo_list = []

def show_tasks():
    if not todo_list:
        print("Your To-Do List is empty.")
    else:
        print("Your To-Do List:")
        for i, task in enumerate(todo_list, start=1):
            print(f"{i}. {task}")

def add_task():
    task = input("Enter a new task: ")
    todo_list.append(task)
    print("Task added successfully!")

def remove_task():
    show_tasks()
    if todo_list:
        try:
            task_num = int(input("Enter the task number to remove: "))
            if 1 <= task_num <= len(todo_list):
                removed = todo_list.pop(task_num - 1)
                print(f"Removed task: {removed}")
            else:
                print("Invalid task number.")
        except ValueError:
            print("Please enter a valid number.")

def main():
    while True:
        print("\nTo-Do List Menu:")
        print("1. Show Tasks")
        print("2. Add Task")
        print("3. Remove Task")
        print("4. Exit")

        choice = input("Enter your choice: ")

        if choice == "1":
            show_tasks()
        elif choice == "2":
            add_task()
        elif choice == "3":
            remove_task()
        elif choice == "4":
            print("Exiting To-Do List. Goodbye!")
            break
        else:
            print("Invalid choice. Please enter a number between 1 and 4.")

if __name__ == "__main__":
    main()
# Out:
# To-Do List Menu:
# 1. Show Tasks
# 2. Add Task
# 3. Remove Task
# 4. Exit
# Enter your choice: 2
# Enter a new task: watch movie
# Task added successfully!
#
# To-Do List Menu:
# 1. Show Tasks
# 2. Add Task
# 3. Remove Task
# 4. Exit
# Enter your choice: 2
# Enter a new task: lunch outside for tonight
# Task added successfully!
#
# To-Do List Menu:
# 1. Show Tasks
# 2. Add Task
# 3. Remove Task
# 4. Exit
# Enter your choice: 1
# Your To-Do List:
# 1. watch movie
# 2. lunch outside for tonight
#
# To-Do List Menu:
# 1. Show Tasks
# 2. Add Task
# 3. Remove Task
# 4. Exit
# Enter your choice: 3
# Your To-Do List:
# 1. watch movie
# 2. lunch outside for tonight
# Enter the task number to remove: 1
# Removed task: watch movie
#
# To-Do List Menu:
# 1. Show Tasks
# 2. Add Task
# 3. Remove Task
# 4. Exit
# Enter your choice: 1
# Your To-Do List:
# 1. lunch outside for tonight
#
# To-Do List Menu:
# 1. Show Tasks
# 2. Add Task
# 3. Remove Task
# 4. Exit
# Enter your choice: 4
# ...
